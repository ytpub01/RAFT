# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# %run /home/ytaima/code/dl-autowarp/viz_preds.py  -u ytaima --id 10027 --show --force
# Out:
# ...
# Processing...: 100%|██████████| 1/1 [00:03<00:00,  3.16s/it]
# Completed 10027
# 31.289993209093776

# %%
plt.imshow(plt.imread("data/warpsds/viz_flows_masked/10027-mag.png"))

# %%
import sys
sys.path.insert(0, "core")

# %%
from core.datasets import AsphereWarp

# %%
aug_params = {'crop_size': (1000, 1000), 'min_scale': -0.1, 'max_scale': 1.0, 'do_flip': True}
ds = AsphereWarp(aug_params)

# %%
result = ds[0]

# %%
len(result)
# Out:
# 5

# %%
img1, img2, flo, valid, extra_info = result
id_ = extra_info.item()

# %%
id_
# Out:
# 10027

# %%
from torchvision.transforms import functional as F

# %%
import torchvision
torchvision.__version__
# Out:
# '0.11.2'

# %%
#from torchvision.utils import flow_to_image

# %%
from core.utils.flow_viz import flow_to_image

# %%
plt.imshow(flow_to_image(flo.permute(1,2,0).numpy()))

# %%
import numpy as np

# %%
u, v = np.mgrid[-1:1:50j, -1:1:50j]
c = u*u + v*v < 1
plt.imshow(flow_to_image(np.dstack([u*c,v*c])))

# %%
flo.shape
# Out:
# torch.Size([2, 1000, 1000])

# %%
img1
# Out:
# tensor([[[63., 59., 55.,  ..., 71., 70., 84.],
#          [58., 56., 54.,  ..., 73., 74., 87.],
#          [51., 51., 51.,  ..., 71., 75., 85.],
#          ...,
#          [78., 74., 72.,  ..., 76., 78., 80.],
#          [82., 77., 71.,  ..., 79., 78., 81.],
#          [82., 76., 70.,  ..., 91., 86., 85.]],
#
#         [[55., 53., 51.,  ..., 65., 64., 78.],
#          [51., 51., 50.,  ..., 68., 69., 81.],
#          [45., 46., 47.,  ..., 67., 70., 80.],
#          ...,
#          [64., 61., 59.,  ..., 74., 76., 78.],
#          [68., 63., 58.,  ..., 77., 76., 79.],
#          [69., 63., 57.,  ..., 89., 84., 84.]],
#
#         [[52., 49., 47.,  ..., 62., 60., 74.],
#          [48., 47., 46.,  ..., 65., 65., 77.],
#          [41., 42., 43.,  ..., 64., 66., 75.],
#          ...,
#          [63., 59., 57.,  ..., 73., 75., 76.],
#          [67., 62., 56.,  ..., 75., 75., 77.],
#          [68., 62., 55.,  ..., 87., 82., 82.]]])

# %%
plt.imshow(F.to_pil_image(img1/255))

# %%
plt.show()

# %%
plt.imshow(F.to_pil_image(img2/255))

# %%
plt.imshow(valid)

# %%
plt.show()

# %%
plt.figure(figsize=(15, 15))
plt.xlim(600, 800)
plt.ylim(0, 200)
# Out:
# (0.0, 200.0)

# %%
from core.utils.frame_utils import read_gen

# %%
plt.imshow(read_gen(f"/data/warpsds_works/satimages/{id_}.png"))

# %%
plt.imshow(plt.imread(f"/data/warpsds_works/satimages/{id_}.png"))

# %%
import numpy as np

# %%
plt.figure(figsize=(15, 15))
plt.xlim(600, 800)
plt.ylim(0, 200)

# %%
plt.subplot(1,2,1)
plt.imshow(np.load(f"/data/warpsds_works/masks/{id_}.npz")["arr_0"])
plt.subplot(1,2,2)
plt.imshow(valid)

# %%
import sys
sys.path.insert(0, os.path.abspath("core"))

# %%
sys.path
# Out:
# ['/home/ytaima/code/dl-autowarp/ext/RAFT/core',
#  'core',
#  '/home/ytaima/code/dl-autowarp/ext/RAFT',
#  '/home/ytaima/code/dl-autowarp/ext/aerial-sphere-desktop',
#  '/home/ytaima/code/dl-autowarp/ext/RAFT/core',
#  '/home/ytaima/code/dl-autowarp/ext/RAFT',
#  '/home/ytaima/anaconda3/envs/asphere3/lib/python37.zip',
#  '/home/ytaima/anaconda3/envs/asphere3/lib/python3.7',
#  '/home/ytaima/anaconda3/envs/asphere3/lib/python3.7/lib-dynload',
#  '',
#  '/home/ytaima/anaconda3/envs/asphere3/lib/python3.7/site-packages',
#  '/home/ytaima/anaconda3/envs/asphere3/lib/python3.7/site-packages/IPython/extensions',
#  '/home/ytaima/.ipython']

# %%
import os
os.path.exists("/home/ytaima/code/dl-autowarp/ext/RAFT/core")
# Out:
# True

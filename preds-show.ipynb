# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#%run viz_preds.py  -u ytaima --id 70065 --show --force

# %%
#plt.imshow(plt.imread("data/warpsds/viz_flows_masked/70065-mag.png"))

# %%
import sys
sys.path.insert(0, "core")

# %%
from core.datasets import AsphereWarp

# %%
aug_params = {'crop_size': (1200, 1200), 'min_scale': -0.1, 'max_scale': 1.0, 'do_flip': True}
ds = AsphereWarp(aug_params)

# %%
result = ds[0]

# %%
len(result)
# Out:
# 5

# %%
img1, img2, flo, valid, extra_info = result

# %%
from torchvision.transforms import functional as F

# %%
import torchvision
torchvision.__version__
# Out:
# '0.11.2'

# %%
#from torchvision.utils import flow_to_image

# %%
from core.utils.flow_viz import flow_to_image

# %%
plt.imshow(flow_to_image(flo.permute(1,2,0).numpy()))

# %%
import numpy as np

# %%
u, v = np.mgrid[-1:1:50j, -1:1:50j]
c = u*u + v*v < 1
plt.imshow(flow_to_image(np.dstack([u*c,v*c])))

# %%
flo.shape
# Out:
# torch.Size([2, 1200, 1200])

# %%
img1
# Out:
# tensor([[[ 74.,  70.,  70.,  ...,  51.,  57.,  55.],
#          [ 74.,  72.,  72.,  ...,  53.,  59.,  58.],
#          [ 74.,  73.,  73.,  ...,  64.,  62.,  60.],
#          ...,
#          [105., 107., 113.,  ...,  34.,  33.,  35.],
#          [104., 106., 113.,  ...,  36.,  37.,  40.],
#          [104., 102., 110.,  ...,  40.,  43.,  46.]],
#
#         [[ 58.,  53.,  53.,  ...,  39.,  44.,  41.],
#          [ 58.,  55.,  55.,  ...,  41.,  46.,  45.],
#          [ 58.,  57.,  57.,  ...,  53.,  49.,  47.],
#          ...,
#          [ 98.,  99., 104.,  ...,  25.,  25.,  27.],
#          [ 98.,  98., 104.,  ...,  28.,  29.,  32.],
#          [ 99.,  95., 101.,  ...,  31.,  34.,  37.]],
#
#         [[ 57.,  53.,  53.,  ...,  37.,  42.,  40.],
#          [ 57.,  55.,  55.,  ...,  40.,  43.,  42.],
#          [ 58.,  56.,  56.,  ...,  51.,  47.,  44.],
#          ...,
#          [ 95.,  96., 102.,  ...,  24.,  23.,  25.],
#          [ 95.,  95., 101.,  ...,  26.,  27.,  29.],
#          [ 95.,  92.,  99.,  ...,  29.,  32.,  35.]]])

# %%
plt.imshow(F.to_pil_image(img1/255))

# %%
plt.imshow(F.to_pil_image(img2/255))

# %%
plt.figure(figsize=(15, 15))
plt.xlim(600, 800)
plt.ylim(0, 200)

# %%
plt.imshow(valid)

# %%
from core.utils.frame_utils import read_gen

# %%
plt.imshow(read_gen(f"/data/warpsds_works/satimages/{id_}.png"))

# %%
id_ = extra_info.item()
plt.imshow(plt.imread(f"/data/warpsds_works/satimages/{id_}.png"))

# %%
import numpy as np

# %%
plt.figure(figsize=(15, 15))
plt.xlim(600, 800)
plt.ylim(0, 200)

# %%
plt.subplot(1,2,1)
plt.imshow(np.load(f"/data/warpsds_works/masks/{id_}.npz")["arr_0"])
plt.subplot(1,2,2)
plt.imshow(valid)

# %%
import sys
sys.path.insert(0, os.path.abspath("core"))

# %%
sys.path
# Out:
# ['/home/ytaima/code/dl-autowarp/ext/RAFT/core',
#  'core',
#  '/home/ytaima/code/dl-autowarp/ext/RAFT',
#  '/home/ytaima/code/dl-autowarp/ext/RAFT/ext/aerial-sphere-desktop',
#  '/home/ytaima/code/dl-autowarp/ext/RAFT/ext/RAFT/core',
#  '/home/ytaima/code/dl-autowarp/ext/RAFT/ext/RAFT',
#  '/home/ytaima/anaconda3/envs/asphere3/lib/python37.zip',
#  '/home/ytaima/anaconda3/envs/asphere3/lib/python3.7',
#  '/home/ytaima/anaconda3/envs/asphere3/lib/python3.7/lib-dynload',
#  '',
#  '/home/ytaima/anaconda3/envs/asphere3/lib/python3.7/site-packages',
#  '/home/ytaima/anaconda3/envs/asphere3/lib/python3.7/site-packages/IPython/extensions',
#  '/home/ytaima/.ipython']

# %%
os.path.exists("/home/ytaima/code/dl-autowarp/ext/RAFT/core")
# Out:
# True

# %%
ls core
# Out:
# corr.py      extractor.py  __pycache__/  update.py
# datasets.py  __init__.py   raft.py       utils/

# %%
ll
# Out:
# total 80968
# drwxrwxr-x 2 ytaima     4096 Apr 26 23:16 alt_cuda_corr/
# -rw-rw-r-- 1 ytaima    45743 Apr 26 23:16 chairs_split.txt
# drwxrwxr-x 2 ytaima     4096 Jun  3 04:24 checkpoints/
# drwxrwxr-x 5 ytaima     4096 May 25 11:01 core/
# lrwxrwxrwx 1 ytaima        5 Jun  3 03:17 datasets -> /data/
# drwxrwxr-x 2 ytaima     4096 Apr 26 23:16 demo-frames/
# -rw-rw-r-- 1 ytaima     2073 Apr 26 23:16 demo.py
# -rwxrwxr-x 1 ytaima       87 Apr 26 23:16 download_models.sh*
# -rw-rw-r-- 1 ytaima     7662 Jun  3 04:04 evaluate.py
# lrwxrwxrwx 1 ytaima       33 Jun  3 03:21 lib -> /home/ytaima/code/dl-autowarp/lib/
# -rw-rw-r-- 1 ytaima     1512 Apr 26 23:16 LICENSE
# drwxrwxr-x 2 ytaima     4096 Jun  1 16:36 models/
# -rw-rw-r-- 1 ytaima 81977417 Apr 27 02:21 models.zip
# -rw-rw-r-- 1 ytaima     2461 Jun  3 05:05 predict.py
# -rw-rw-r-- 1 ytaima    10747 Jun 10 12:39 preds-show.ipynb
# drwxrwxr-x 2 ytaima     4096 May 27 20:04 __pycache__/
# -rw-rw-r-- 1 ytaima   204077 Apr 26 23:16 RAFT.png
# -rw-rw-r-- 1 ytaima     2809 Apr 26 23:16 README.md
# drwxrwxr-x 4 ytaima     4096 Jun  2 11:24 runs/
# -rwxrwxr-x 1 ytaima      322 Apr 26 23:16 train-asphere-dbg.sh*
# -rwxrwxr-x 1 ytaima      312 Apr 26 23:16 train-asphere-init.sh*
# -rwxrwxr-x 1 ytaima      302 Jun  2 10:40 train-asphere.sh*
# -rw-rw-r-- 1 ytaima   332739 Jun  2 11:24 train.log
# -rwxrwxr-x 1 ytaima      957 Apr 26 23:16 train_mixed.sh*
# -rw-rw-r-- 1 ytaima     9530 Jun  2 11:00 train.py
# -rwxrwxr-x 1 ytaima      896 Apr 26 23:16 train_standard.sh*
# -rw-rw-r-- 1 ytaima   229772 Jun 10 11:52 Untitled-1.ipynb
# -rw-rw-r-- 1 ytaima      574 Apr 26 23:16 valdata.py
